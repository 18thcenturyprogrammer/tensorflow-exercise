# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
data_from_csv = pd.read_csv("pima-indians-diabetes.csv")

# %%
data_from_csv.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
data_from_csv.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
cols_to_be_normalized = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
# https://www.quora.com/What-is-the-meaning-of-min-max-normalization
#  this is min-max normalization 
#  the value range will be 0 - 1 
data_from_csv[cols_to_be_normalized] = data_from_csv[cols_to_be_normalized].apply(lambda x: (x-x.min())/ (x.max()-x.min()))

# %%
data_from_csv.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
num_preg = tf.feature_column.numeric_column("Number_pregnant")
gluc_concent = tf.feature_column.numeric_column("Glucose_concentration")
bld_press = tf.feature_column.numeric_column("Blood_pressure")
tri = tf.feature_column.numeric_column("Triceps")
insul = tf.feature_column.numeric_column("Insulin")
bmi = tf.feature_column.numeric_column("BMI")
pedi = tf.feature_column.numeric_column("Pedigree")
age = tf.feature_column.numeric_column("Age")

# %%
# categorical data를 처리하는 방법을 보여주고 있다. 가장 많이 사용하는 것이 categorical_column_with_vocabulary_list 와 categorical_column_with_hash_bucket
# 이다. hash_bucket_size는 해당 data column에 최대 몇가지 종류의 data가 있을지에 대한 예상값이다
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list("Group",["A","B","C","D"])

# %%
assigned_group2 = tf.feature_column.categorical_column_with_hash_bucket("Group",hash_bucket_size=10)

# %%
data_from_csv["Age"]
# Out:
# 0      50
# 1      31
# 2      32
# 3      21
# 4      33
# 5      30
# 6      26
# 7      29
# 8      53
# 9      54
# 10     30
# 11     34
# 12     57
# 13     59
# 14     51
# 15     32
# 16     31
# 17     31
# 18     33
# 19     32
# 20     27
# 21     50
# 22     41
# 23     29
# 24     51
# 25     41
# 26     43
# 27     22
# 28     57
# 29     38
#        ..
# 738    21
# 739    42
# 740    48
# 741    26
# 742    22
# 743    45
# 744    39
# 745    46
# 746    27
# 747    32
# 748    36
# 749    50
# 750    22
# 751    28
# 752    25
# 753    26
# 754    45
# 755    37
# 756    39
# 757    52
# 758    26
# 759    66
# 760    22
# 761    43
# 762    33
# 763    63
# 764    27
# 765    30
# 766    47
# 767    23
# Name: Age, Length: 768, dtype: int64

# %%
# bins mean how many boundaries uses in the histogram
data_from_csv["Age"].hist(bins=20)

# same results as above
# plt.hist(data_from_csv["Age"],bins=10)

# %%
# bucketized_column() takes feature_column obj as 1st argument
bucketized_age = tf.feature_column.bucketized_column(age,boundaries=[20,30,40,50,60,70,80,90])

# %%
feature_cols = [num_preg,gluc_concent,bld_press,tri,insul,bmi,pedi,assigned_group,bucketized_age]

# %%
x_data = data_from_csv.drop("Class",axis=1)

# %%
y = data_from_csv["Class"]

# %%
x_data.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age Group
# 0  0.500745  0.234415   50     B
# 1  0.396423  0.116567   31     C
# 2  0.347243  0.253629   32     B
# 3  0.418778  0.038002   21     B
# 4  0.642325  0.943638   33     C

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data, y, test_size=0.33, random_state=42)

# %%
train_input_func = tf.estimator.inputs.pandas_input_fn(x= X_train, y= y_train , batch_size=10, num_epochs= 1000, shuffle=True)

# %%
model = tf.estimator.LinearClassifier(feature_columns= feature_cols)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/9c/883h376s53500dcqng4b4nj00000gn/T/tmpemyxo1wb
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/9c/883h376s53500dcqng4b4nj00000gn/T/tmpemyxo1wb', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1c4230bbe0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %% [markdown]
# #### An epoch usually means one iteration over all of the training data. For instance if you have 20,000 images and a batch size of 100 then the epoch should contain 20,000 / 100 = 200 steps. However I usually just set a fixed number of steps like 1000 per epoch even though I have a much larger data set. At the end of the epoch I check the average cost and if it improved I save a checkpoint. There is no difference between steps from one epoch to another. I just treat them as checkpoints.
#
# #### People often shuffle around the data set between epochs. I prefer to use the random.sample function to choose the data to process in my epochs. So say I want to do 1000 steps with a batch size of 32. I will just randomly pick 32,000 samples from the pool of training data.
#
# #### ref) https://stackoverflow.com/a/38340420/3151712
#
# #### A training step is one gradient update. In one step batch_size many examples are processed.
#
# #### An epoch consists of one full cycle through the training data. This is usually many steps. As an example, if you have 2,000 images and use a batch size of 10 an epoch consists of 2,000 images / (10 images / step) = 200 steps.
#
# #### If you choose our training image randomly (and independent) in each step, you normally do not call it epoch. [This is where my answer differs from the previous one. Also see my comment.]
#
# #### ref) https://stackoverflow.com/a/44416034/3151712

# %%
model.train(input_fn= train_input_func,steps= 1000)
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/feature_column/feature_column_v2.py:2703: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/feature_column/feature_column_v2.py:2898: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/training/monitored_session.py:809: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into /var/folders/9c/883h376s53500dcqng4b4nj00000gn/T/tmpemyxo1wb/model.ckpt.
# INFO:tensorflow:loss = 6.931472, step = 1
# INFO:tensorflow:global_step/sec: 163.383
# INFO:tensorflow:loss = 6.524698, step = 101 (0.612 sec)
# INFO:tensorflow:global_step/sec: 289.468
# INFO:tensorflow:loss = 6.3655853, step = 201 (0.345 sec)
# INFO:tensorflow:global_step/sec: 272.775
# INFO:tensorflow:loss = 3.8059907, step = 301 (0.367 sec)
# INFO:tensorflow:global_step/sec: 296.075
# INFO:tensorflow:loss = 5.5656495, step = 401 (0.343 sec)
# INFO:tensorflow:global_step/sec: 281.915
# INFO:tensorflow:loss = 5.609375, step = 501 (0.355 sec)
# INFO:tensorflow:global_step/sec: 279.91
# INFO:tensorflow:loss = 6.4544926, step = 601 (0.358 sec)
# INFO:tensorflow:global_step/sec: 288.671
# INFO:tensorflow:loss = 3.945579, step = 701 (0.339 sec)
# INFO:tensorflow:global_step/sec: 274.351
# INFO:tensorflow:loss = 3.95422, step = 801 (0.369 sec)
# INFO:tensorflow:global_step/sec: 300.4
# INFO:tensorflow:loss = 4.0952744, step = 901 (0.331 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/9c/883h376s53500dcqng4b4nj00000gn/T/tmpemyxo1wb/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.565792.

# %%
test_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test, y= y_test, batch_size= 10, num_epochs=1, shuffle=False )

# %%
results = model.evaluate(test_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/metrics_impl.py:2002: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-11T17:34:56Z
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /var/folders/9c/883h376s53500dcqng4b4nj00000gn/T/tmpemyxo1wb/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-04-11-17:34:57
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.72440946, accuracy_baseline = 0.66141737, auc = 0.7538414, auc_precision_recall = 0.5752216, average_loss = 0.54984623, global_step = 1000, label/mean = 0.33858266, loss = 5.371575, precision = 0.62903225, prediction/mean = 0.34381595, recall = 0.45348838
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /var/folders/9c/883h376s53500dcqng4b4nj00000gn/T/tmpemyxo1wb/model.ckpt-1000

# %%
results
# Out:
# {'accuracy': 0.72440946,
#  'accuracy_baseline': 0.66141737,
#  'auc': 0.7538414,
#  'auc_precision_recall': 0.5752216,
#  'average_loss': 0.54984623,
#  'label/mean': 0.33858266,
#  'loss': 5.371575,
#  'precision': 0.62903225,
#  'prediction/mean': 0.34381595,
#  'recall': 0.45348838,
#  'global_step': 1000}

# %%
# this is should be different from test input func above, but we used same data for simplicity
# there is no y values for predictions
pred_input_func = tf.estimator.inputs.pandas_input_fn(x= X_test, batch_size= 10 , num_epochs= 1, shuffle= False)

# %%
predictions = model.predict(pred_input_func)

# %%
predictions
# Out:
# <generator object EstimatorV2.predict at 0x1a37cf31b0>

# %%
list(predictions)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/9c/883h376s53500dcqng4b4nj00000gn/T/tmpemyxo1wb/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'logits': array([0.2624181], dtype=float32),
#   'logistic': array([0.5652306], dtype=float32),
#   'probabilities': array([0.43476936, 0.5652306 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.7377222], dtype=float32),
#   'logistic': array([0.1496025], dtype=float32),
#   'probabilities': array([0.85039747, 0.14960249], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5078255], dtype=float32),
#   'logistic': array([0.18126127], dtype=float32),
#   'probabilities': array([0.81873876, 0.18126129], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.44073015], dtype=float32),
#   'logistic': array([0.391567], dtype=float32),
#   'probabilities': array([0.608433  , 0.39156702], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.18676811], dtype=float32),
#   'logistic': array([0.5465568], dtype=float32),
#   'probabilities': array([0.45344323, 0.5465568 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.43122047], dtype=float32),
#   'logistic': array([0.60616505], dtype=float32),
#   'probabilities': array([0.39383492, 0.60616505], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.7535871], dtype=float32),
#   'logistic': array([0.14759529], dtype=float32),
#   'probabilities': array([0.85240465, 0.14759533], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.42611223], dtype=float32),
#   'logistic': array([0.60494494], dtype=float32),
#   'probabilities': array([0.3950551 , 0.60494494], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.20777363], dtype=float32),
#   'logistic': array([0.55175734], dtype=float32),
#   'probabilities': array([0.44824266, 0.55175734], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.42183638], dtype=float32),
#   'logistic': array([0.3960774], dtype=float32),
#   'probabilities': array([0.6039226 , 0.39607742], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.4060939], dtype=float32),
#   'logistic': array([0.39984912], dtype=float32),
#   'probabilities': array([0.6001509, 0.3998491], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.04658717], dtype=float32),
#   'logistic': array([0.4883553], dtype=float32),
#   'probabilities': array([0.51164466, 0.4883553 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0501771], dtype=float32),
#   'logistic': array([0.2591911], dtype=float32),
#   'probabilities': array([0.7408089, 0.2591911], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.21213704], dtype=float32),
#   'logistic': array([0.55283624], dtype=float32),
#   'probabilities': array([0.44716373, 0.55283624], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.5326214], dtype=float32),
#   'logistic': array([0.17761046], dtype=float32),
#   'probabilities': array([0.8223895 , 0.17761046], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0023433], dtype=float32),
#   'logistic': array([0.26848096], dtype=float32),
#   'probabilities': array([0.73151904, 0.26848096], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.0712066], dtype=float32),
#   'logistic': array([0.11192703], dtype=float32),
#   'probabilities': array([0.8880729 , 0.11192704], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6818926], dtype=float32),
#   'logistic': array([0.156845], dtype=float32),
#   'probabilities': array([0.84315497, 0.156845  ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.0006097], dtype=float32),
#   'logistic': array([0.5001524], dtype=float32),
#   'probabilities': array([0.49984756, 0.5001524 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.6820812], dtype=float32),
#   'logistic': array([0.33579695], dtype=float32),
#   'probabilities': array([0.66420305, 0.33579692], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.45977777], dtype=float32),
#   'logistic': array([0.38703856], dtype=float32),
#   'probabilities': array([0.6129615 , 0.38703856], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6244333], dtype=float32),
#   'logistic': array([0.16459438], dtype=float32),
#   'probabilities': array([0.83540565, 0.16459438], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.42249435], dtype=float32),
#   'logistic': array([0.39592004], dtype=float32),
#   'probabilities': array([0.60407996, 0.39592   ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4860879], dtype=float32),
#   'logistic': array([0.18450963], dtype=float32),
#   'probabilities': array([0.81549037, 0.18450963], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.0684855], dtype=float32),
#   'logistic': array([0.4828853], dtype=float32),
#   'probabilities': array([0.5171147 , 0.48288533], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.3381452], dtype=float32),
#   'logistic': array([0.5837399], dtype=float32),
#   'probabilities': array([0.4162601, 0.5837399], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.6736298], dtype=float32),
#   'logistic': array([0.1579408], dtype=float32),
#   'probabilities': array([0.8420592 , 0.15794085], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.0806081], dtype=float32),
#   'logistic': array([0.11099598], dtype=float32),
#   'probabilities': array([0.8890041 , 0.11099595], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5749507], dtype=float32),
#   'logistic': array([0.17151177], dtype=float32),
#   'probabilities': array([0.82848823, 0.17151178], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.9102141], dtype=float32),
#   'logistic': array([0.28695604], dtype=float32),
#   'probabilities': array([0.713044  , 0.28695604], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.70198536], dtype=float32),
#   'logistic': array([0.3313722], dtype=float32),
#   'probabilities': array([0.6686278 , 0.33137217], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.2274273], dtype=float32),
#   'logistic': array([0.44338697], dtype=float32),
#   'probabilities': array([0.556613  , 0.44338697], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.23713142], dtype=float32),
#   'logistic': array([0.55900663], dtype=float32),
#   'probabilities': array([0.4409934 , 0.55900663], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.6924704], dtype=float32),
#   'logistic': array([0.6665162], dtype=float32),
#   'probabilities': array([0.33348373, 0.66651624], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.42817563], dtype=float32),
#   'logistic': array([0.60543793], dtype=float32),
#   'probabilities': array([0.39456204, 0.60543793], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.06892776], dtype=float32),
#   'logistic': array([0.48277488], dtype=float32),
#   'probabilities': array([0.51722515, 0.48277488], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.4631874], dtype=float32),
#   'logistic': array([0.61377], dtype=float32),
#   'probabilities': array([0.38622996, 0.61377   ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.18067825], dtype=float32),
#   'logistic': array([0.45495293], dtype=float32),
#   'probabilities': array([0.54504704, 0.45495287], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.6921153], dtype=float32),
#   'logistic': array([0.3335627], dtype=float32),
#   'probabilities': array([0.6664373 , 0.33356267], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.7384548], dtype=float32),
#   'logistic': array([0.3233421], dtype=float32),
#   'probabilities': array([0.67665786, 0.3233421 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.735019], dtype=float32),
#   'logistic': array([0.14994669], dtype=float32),
#   'probabilities': array([0.8500533 , 0.14994672], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.3190344], dtype=float32),
#   'logistic': array([0.4209111], dtype=float32),
#   'probabilities': array([0.5790889 , 0.42091107], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.55579317], dtype=float32),
#   'logistic': array([0.36452138], dtype=float32),
#   'probabilities': array([0.6354786, 0.3645214], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.88741153], dtype=float32),
#   'logistic': array([0.2916443], dtype=float32),
#   'probabilities': array([0.7083557 , 0.29164428], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9951117], dtype=float32),
#   'logistic': array([0.11971715], dtype=float32),
#   'probabilities': array([0.8802829 , 0.11971711], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.5780022], dtype=float32),
#   'logistic': array([0.3593924], dtype=float32),
#   'probabilities': array([0.6406076 , 0.35939243], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.4702706], dtype=float32),
#   'logistic': array([0.8130985], dtype=float32),
#   'probabilities': array([0.18690148, 0.8130985 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.9408197], dtype=float32),
#   'logistic': array([0.12555781], dtype=float32),
#   'probabilities': array([0.8744422 , 0.12555784], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.6617239], dtype=float32),
#   'logistic': array([0.6596475], dtype=float32),
#   'probabilities': array([0.34035248, 0.6596475 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.0588572], dtype=float32),
#   'logistic': array([0.8868395], dtype=float32),
#   'probabilities': array([0.11316045, 0.8868395 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.7278442], dtype=float32),
#   'logistic': array([0.15086353], dtype=float32),
#   'probabilities': array([0.8491365 , 0.15086353], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.2418628], dtype=float32),
#   'logistic': array([0.7758881], dtype=float32),
#   'probabilities': array([0.2241119, 0.7758881], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.4535396], dtype=float32),
#   'logistic': array([0.8105426], dtype=float32),
#   'probabilities': array([0.1894574, 0.8105425], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.5305002], dtype=float32),
#   'logistic': array([0.17792049], dtype=float32),
#   'probabilities': array([0.82207954, 0.17792052], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0156822], dtype=float32),
#   'logistic': array([0.26586932], dtype=float32),
#   'probabilities': array([0.73413074, 0.26586932], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.2125552], dtype=float32),
#   'logistic': array([0.09862867], dtype=float32),
#   'probabilities': array([0.90137136, 0.09862868], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.34979647], dtype=float32),
#   'logistic': array([0.4134318], dtype=float32),
#   'probabilities': array([0.5865682 , 0.41343176], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9935179], dtype=float32),
#   'logistic': array([0.11988518], dtype=float32),
#   'probabilities': array([0.8801148 , 0.11988518], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3191571], dtype=float32),
#   'logistic': array([0.21095854], dtype=float32),
#   'probabilities': array([0.78904146, 0.21095857], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.24964088], dtype=float32),
#   'logistic': array([0.56208813], dtype=float32),
#   'probabilities': array([0.4379119 , 0.56208813], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.19124311], dtype=float32),
#   'logistic': array([0.5476656], dtype=float32),
#   'probabilities': array([0.45233443, 0.5476656 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.3072214], dtype=float32),
#   'logistic': array([0.21295217], dtype=float32),
#   'probabilities': array([0.78704786, 0.21295218], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.21110517], dtype=float32),
#   'logistic': array([0.44741884], dtype=float32),
#   'probabilities': array([0.55258113, 0.4474188 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.23690635], dtype=float32),
#   'logistic': array([0.55895114], dtype=float32),
#   'probabilities': array([0.4410489 , 0.55895114], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.7866488], dtype=float32),
#   'logistic': array([0.14348409], dtype=float32),
#   'probabilities': array([0.8565159 , 0.14348409], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3250582], dtype=float32),
#   'logistic': array([0.20997798], dtype=float32),
#   'probabilities': array([0.790022  , 0.20997797], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.0595238], dtype=float32),
#   'logistic': array([0.11309358], dtype=float32),
#   'probabilities': array([0.8869064 , 0.11309358], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.09268898], dtype=float32),
#   'logistic': array([0.47684434], dtype=float32),
#   'probabilities': array([0.5231557 , 0.47684437], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.741039], dtype=float32),
#   'logistic': array([0.14918101], dtype=float32),
#   'probabilities': array([0.850819  , 0.14918101], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.29028207], dtype=float32),
#   'logistic': array([0.5720652], dtype=float32),
#   'probabilities': array([0.4279348, 0.5720652], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.7986532], dtype=float32),
#   'logistic': array([0.6896863], dtype=float32),
#   'probabilities': array([0.3103137 , 0.68968636], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.74011916], dtype=float32),
#   'logistic': array([0.32297808], dtype=float32),
#   'probabilities': array([0.6770219 , 0.32297808], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.2368781], dtype=float32),
#   'logistic': array([0.55894417], dtype=float32),
#   'probabilities': array([0.44105583, 0.55894417], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.468113], dtype=float32),
#   'logistic': array([0.18722957], dtype=float32),
#   'probabilities': array([0.81277037, 0.1872296 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.0369754], dtype=float32),
#   'logistic': array([0.11537507], dtype=float32),
#   'probabilities': array([0.8846249 , 0.11537507], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0102968], dtype=float32),
#   'logistic': array([0.26692176], dtype=float32),
#   'probabilities': array([0.7330782 , 0.26692176], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.18291408], dtype=float32),
#   'logistic': array([0.5456014], dtype=float32),
#   'probabilities': array([0.45439854, 0.5456014 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.2630567], dtype=float32),
#   'logistic': array([0.43461245], dtype=float32),
#   'probabilities': array([0.56538755, 0.43461245], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3479286], dtype=float32),
#   'logistic': array([0.20620923], dtype=float32),
#   'probabilities': array([0.7937908 , 0.20620921], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.9577369], dtype=float32),
#   'logistic': array([0.27733153], dtype=float32),
#   'probabilities': array([0.7226684, 0.2773315], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.31674272], dtype=float32),
#   'logistic': array([0.4214698], dtype=float32),
#   'probabilities': array([0.57853025, 0.42146978], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6907473], dtype=float32),
#   'logistic': array([0.15567759], dtype=float32),
#   'probabilities': array([0.8443224 , 0.15567759], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.94768834], dtype=float32),
#   'logistic': array([0.27934995], dtype=float32),
#   'probabilities': array([0.7206501 , 0.27934995], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.386456], dtype=float32),
#   'logistic': array([0.19997412], dtype=float32),
#   'probabilities': array([0.8000259 , 0.19997413], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0756665], dtype=float32),
#   'logistic': array([0.254327], dtype=float32),
#   'probabilities': array([0.745673  , 0.25432694], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.7267098], dtype=float32),
#   'logistic': array([0.6740828], dtype=float32),
#   'probabilities': array([0.32591715, 0.6740829 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.26166326], dtype=float32),
#   'logistic': array([0.5650451], dtype=float32),
#   'probabilities': array([0.4349549, 0.5650451], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.16552263], dtype=float32),
#   'logistic': array([0.5412864], dtype=float32),
#   'probabilities': array([0.45871353, 0.5412864 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.0760577], dtype=float32),
#   'logistic': array([0.2542528], dtype=float32),
#   'probabilities': array([0.74574727, 0.2542528 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5510161], dtype=float32),
#   'logistic': array([0.17493956], dtype=float32),
#   'probabilities': array([0.8250604 , 0.17493956], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6967747], dtype=float32),
#   'logistic': array([0.15488699], dtype=float32),
#   'probabilities': array([0.84511304, 0.15488698], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.0344045], dtype=float32),
#   'logistic': array([0.11563772], dtype=float32),
#   'probabilities': array([0.8843623 , 0.11563773], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.4225414], dtype=float32),
#   'logistic': array([0.08146986], dtype=float32),
#   'probabilities': array([0.91853017, 0.08146988], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.12864673], dtype=float32),
#   'logistic': array([0.4678826], dtype=float32),
#   'probabilities': array([0.5321174, 0.4678826], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.7096302], dtype=float32),
#   'logistic': array([0.32968056], dtype=float32),
#   'probabilities': array([0.67031944, 0.32968056], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.81822324], dtype=float32),
#   'logistic': array([0.30614096], dtype=float32),
#   'probabilities': array([0.69385904, 0.30614093], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.0304969], dtype=float32),
#   'logistic': array([0.49237636], dtype=float32),
#   'probabilities': array([0.5076236 , 0.49237633], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4612106], dtype=float32),
#   'logistic': array([0.18828222], dtype=float32),
#   'probabilities': array([0.81171775, 0.18828222], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.26122946], dtype=float32),
#   'logistic': array([0.4350615], dtype=float32),
#   'probabilities': array([0.5649385 , 0.43506148], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.7453392], dtype=float32),
#   'logistic': array([0.32183772], dtype=float32),
#   'probabilities': array([0.67816234, 0.32183772], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.81718785], dtype=float32),
#   'logistic': array([0.69363904], dtype=float32),
#   'probabilities': array([0.30636093, 0.69363904], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.6904943], dtype=float32),
#   'logistic': array([0.15571082], dtype=float32),
#   'probabilities': array([0.8442892 , 0.15571085], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.3428753], dtype=float32),
#   'logistic': array([0.5848888], dtype=float32),
#   'probabilities': array([0.4151112, 0.5848888], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.83508444], dtype=float32),
#   'logistic': array([0.30257106], dtype=float32),
#   'probabilities': array([0.69742894, 0.30257106], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.14578348], dtype=float32),
#   'logistic': array([0.46361855], dtype=float32),
#   'probabilities': array([0.5363815 , 0.46361858], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2574463], dtype=float32),
#   'logistic': array([0.22141382], dtype=float32),
#   'probabilities': array([0.77858615, 0.2214138 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1856455], dtype=float32),
#   'logistic': array([0.23403862], dtype=float32),
#   'probabilities': array([0.76596135, 0.23403865], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.2471841], dtype=float32),
#   'logistic': array([0.56148326], dtype=float32),
#   'probabilities': array([0.4385167 , 0.56148326], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.7299622], dtype=float32),
#   'logistic': array([0.15059242], dtype=float32),
#   'probabilities': array([0.84940755, 0.1505924 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.08250147], dtype=float32),
#   'logistic': array([0.5206137], dtype=float32),
#   'probabilities': array([0.47938633, 0.5206137 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-2.0032234], dtype=float32),
#   'logistic': array([0.11886489], dtype=float32),
#   'probabilities': array([0.8811351 , 0.11886489], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4025483], dtype=float32),
#   'logistic': array([0.19741201], dtype=float32),
#   'probabilities': array([0.802588  , 0.19741204], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8766087], dtype=float32),
#   'logistic': array([0.13277885], dtype=float32),
#   'probabilities': array([0.8672211, 0.1327789], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.7116268], dtype=float32),
#   'logistic': array([0.6707605], dtype=float32),
#   'probabilities': array([0.3292395, 0.6707606], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.5184214], dtype=float32),
#   'logistic': array([0.17969409], dtype=float32),
#   'probabilities': array([0.8203059 , 0.17969409], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.546066], dtype=float32),
#   'logistic': array([0.17565516], dtype=float32),
#   'probabilities': array([0.8243448 , 0.17565519], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.7142532], dtype=float32),
#   'logistic': array([0.3286597], dtype=float32),
#   'probabilities': array([0.6713403 , 0.32865974], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3840132], dtype=float32),
#   'logistic': array([0.20036525], dtype=float32),
#   'probabilities': array([0.7996347 , 0.20036523], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.0741138], dtype=float32),
#   'logistic': array([0.11163839], dtype=float32),
#   'probabilities': array([0.88836163, 0.1116384 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3068833], dtype=float32),
#   'logistic': array([0.21300882], dtype=float32),
#   'probabilities': array([0.7869912 , 0.21300885], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5928156], dtype=float32),
#   'logistic': array([0.16898811], dtype=float32),
#   'probabilities': array([0.8310119 , 0.16898814], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2091312], dtype=float32),
#   'logistic': array([0.22985482], dtype=float32),
#   'probabilities': array([0.77014524, 0.22985482], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8328454], dtype=float32),
#   'logistic': array([0.13789967], dtype=float32),
#   'probabilities': array([0.86210036, 0.13789965], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7192883], dtype=float32),
#   'logistic': array([0.15196285], dtype=float32),
#   'probabilities': array([0.8480372 , 0.15196285], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2643126], dtype=float32),
#   'logistic': array([0.2202324], dtype=float32),
#   'probabilities': array([0.7797676 , 0.22023238], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.4982293], dtype=float32),
#   'logistic': array([0.3779569], dtype=float32),
#   'probabilities': array([0.62204313, 0.37795687], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.7805842], dtype=float32),
#   'logistic': array([0.31419402], dtype=float32),
#   'probabilities': array([0.68580604, 0.314194  ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.1098783], dtype=float32),
#   'logistic': array([0.7521064], dtype=float32),
#   'probabilities': array([0.24789357, 0.75210637], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.8708058], dtype=float32),
#   'logistic': array([0.7049133], dtype=float32),
#   'probabilities': array([0.29508665, 0.7049133 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.1790517], dtype=float32),
#   'logistic': array([0.5446437], dtype=float32),
#   'probabilities': array([0.45535627, 0.5446437 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.25813335], dtype=float32),
#   'logistic': array([0.5641774], dtype=float32),
#   'probabilities': array([0.43582267, 0.5641774 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.49680632], dtype=float32),
#   'logistic': array([0.6217085], dtype=float32),
#   'probabilities': array([0.3782915, 0.6217085], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.3756785], dtype=float32),
#   'logistic': array([0.20170394], dtype=float32),
#   'probabilities': array([0.79829603, 0.20170394], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.15078646], dtype=float32),
#   'logistic': array([0.46237466], dtype=float32),
#   'probabilities': array([0.5376253 , 0.46237463], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.35847247], dtype=float32),
#   'logistic': array([0.4113294], dtype=float32),
#   'probabilities': array([0.5886706, 0.4113294], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.7270771], dtype=float32),
#   'logistic': array([0.32583648], dtype=float32),
#   'probabilities': array([0.6741635 , 0.32583645], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5612481], dtype=float32),
#   'logistic': array([0.1734676], dtype=float32),
#   'probabilities': array([0.8265324 , 0.17346765], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.39700848], dtype=float32),
#   'logistic': array([0.5979687], dtype=float32),
#   'probabilities': array([0.4020313, 0.5979687], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.9922733], dtype=float32),
#   'logistic': array([0.72953665], dtype=float32),
#   'probabilities': array([0.2704633 , 0.72953665], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-2.3264003], dtype=float32),
#   'logistic': array([0.08895997], dtype=float32),
#   'probabilities': array([0.91104007, 0.08895998], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8306684], dtype=float32),
#   'logistic': array([0.13815862], dtype=float32),
#   'probabilities': array([0.8618414 , 0.13815866], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.1227326], dtype=float32),
#   'logistic': array([0.10690686], dtype=float32),
#   'probabilities': array([0.89309305, 0.10690688], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3449346], dtype=float32),
#   'logistic': array([0.20669973], dtype=float32),
#   'probabilities': array([0.7933003 , 0.20669974], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.34605098], dtype=float32),
#   'logistic': array([0.41434038], dtype=float32),
#   'probabilities': array([0.5856596 , 0.41434038], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8524971], dtype=float32),
#   'logistic': array([0.13557997], dtype=float32),
#   'probabilities': array([0.86442006, 0.13557997], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.99668056], dtype=float32),
#   'logistic': array([0.2695946], dtype=float32),
#   'probabilities': array([0.73040545, 0.26959458], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.4581111], dtype=float32),
#   'logistic': array([0.38743404], dtype=float32),
#   'probabilities': array([0.612566, 0.387434], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9620731], dtype=float32),
#   'logistic': array([0.12324286], dtype=float32),
#   'probabilities': array([0.87675714, 0.12324286], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.25624496], dtype=float32),
#   'logistic': array([0.43628702], dtype=float32),
#   'probabilities': array([0.563713  , 0.43628702], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.04871124], dtype=float32),
#   'logistic': array([0.4878246], dtype=float32),
#   'probabilities': array([0.5121754, 0.4878246], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6690587], dtype=float32),
#   'logistic': array([0.15854973], dtype=float32),
#   'probabilities': array([0.8414503 , 0.15854973], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.58113176], dtype=float32),
#   'logistic': array([0.64132774], dtype=float32),
#   'probabilities': array([0.3586722 , 0.64132774], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.99448025], dtype=float32),
#   'logistic': array([0.27002805], dtype=float32),
#   'probabilities': array([0.7299719 , 0.27002802], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.81040907], dtype=float32),
#   'logistic': array([0.30780336], dtype=float32),
#   'probabilities': array([0.69219667, 0.30780333], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8950868], dtype=float32),
#   'logistic': array([0.13066554], dtype=float32),
#   'probabilities': array([0.86933446, 0.13066557], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.538106], dtype=float32),
#   'logistic': array([0.63137174], dtype=float32),
#   'probabilities': array([0.3686283 , 0.63137174], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.9545911], dtype=float32),
#   'logistic': array([0.27796248], dtype=float32),
#   'probabilities': array([0.72203755, 0.27796245], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.65923035], dtype=float32),
#   'logistic': array([0.34091255], dtype=float32),
#   'probabilities': array([0.6590874, 0.3409125], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.48585385], dtype=float32),
#   'logistic': array([0.61912924], dtype=float32),
#   'probabilities': array([0.38087082, 0.61912924], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.1220343], dtype=float32),
#   'logistic': array([0.24563414], dtype=float32),
#   'probabilities': array([0.75436586, 0.24563414], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0534433], dtype=float32),
#   'logistic': array([0.25856447], dtype=float32),
#   'probabilities': array([0.7414356 , 0.25856444], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.62361974], dtype=float32),
#   'logistic': array([0.6510413], dtype=float32),
#   'probabilities': array([0.34895864, 0.6510413 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.4943681], dtype=float32),
#   'logistic': array([0.18326703], dtype=float32),
#   'probabilities': array([0.81673294, 0.183267  ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.873435], dtype=float32),
#   'logistic': array([0.13314474], dtype=float32),
#   'probabilities': array([0.8668552 , 0.13314475], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2766562], dtype=float32),
#   'logistic': array([0.21811992], dtype=float32),
#   'probabilities': array([0.78188   , 0.21811995], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.9971622], dtype=float32),
#   'logistic': array([0.26949978], dtype=float32),
#   'probabilities': array([0.7305003 , 0.26949972], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7658032], dtype=float32),
#   'logistic': array([0.14606503], dtype=float32),
#   'probabilities': array([0.85393494, 0.14606501], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2329147], dtype=float32),
#   'logistic': array([0.22567168], dtype=float32),
#   'probabilities': array([0.7743283, 0.2256717], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.18694776], dtype=float32),
#   'logistic': array([0.5466013], dtype=float32),
#   'probabilities': array([0.4533987, 0.5466013], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.08776504], dtype=float32),
#   'logistic': array([0.47807282], dtype=float32),
#   'probabilities': array([0.5219272, 0.4780728], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.11268395], dtype=float32),
#   'logistic': array([0.5281412], dtype=float32),
#   'probabilities': array([0.47185877, 0.5281412 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.4968729], dtype=float32),
#   'logistic': array([0.18289235], dtype=float32),
#   'probabilities': array([0.8171076 , 0.18289238], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.63867736], dtype=float32),
#   'logistic': array([0.3455456], dtype=float32),
#   'probabilities': array([0.6544544 , 0.34554556], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.5949406], dtype=float32),
#   'logistic': array([0.35550207], dtype=float32),
#   'probabilities': array([0.64449793, 0.35550204], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.79844874], dtype=float32),
#   'logistic': array([0.68964255], dtype=float32),
#   'probabilities': array([0.31035745, 0.68964255], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.4228158], dtype=float32),
#   'logistic': array([0.19422054], dtype=float32),
#   'probabilities': array([0.80577946, 0.19422053], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.04450488], dtype=float32),
#   'logistic': array([0.48887563], dtype=float32),
#   'probabilities': array([0.5111244, 0.4888756], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.28261858], dtype=float32),
#   'logistic': array([0.42981192], dtype=float32),
#   'probabilities': array([0.57018805, 0.4298119 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.34486228], dtype=float32),
#   'logistic': array([0.58537114], dtype=float32),
#   'probabilities': array([0.41462883, 0.58537114], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.08769959], dtype=float32),
#   'logistic': array([0.47808915], dtype=float32),
#   'probabilities': array([0.52191085, 0.47808912], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.439349], dtype=float32),
#   'logistic': array([0.6081039], dtype=float32),
#   'probabilities': array([0.3918961 , 0.60810393], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.8803916], dtype=float32),
#   'logistic': array([0.29309666], dtype=float32),
#   'probabilities': array([0.70690334, 0.29309663], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.00916731], dtype=float32),
#   'logistic': array([0.4977082], dtype=float32),
#   'probabilities': array([0.5022918 , 0.49770817], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3023412], dtype=float32),
#   'logistic': array([0.21377128], dtype=float32),
#   'probabilities': array([0.7862288 , 0.21377127], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.57301444], dtype=float32),
#   'logistic': array([0.6394584], dtype=float32),
#   'probabilities': array([0.36054158, 0.6394585 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.6659565], dtype=float32),
#   'logistic': array([0.15896404], dtype=float32),
#   'probabilities': array([0.84103596, 0.15896402], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.940422], dtype=float32),
#   'logistic': array([0.12560147], dtype=float32),
#   'probabilities': array([0.87439847, 0.1256015 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3200818], dtype=float32),
#   'logistic': array([0.2108047], dtype=float32),
#   'probabilities': array([0.7891953 , 0.21080467], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.6650997], dtype=float32),
#   'logistic': array([0.66040504], dtype=float32),
#   'probabilities': array([0.33959496, 0.66040504], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.2590915], dtype=float32),
#   'logistic': array([0.43558702], dtype=float32),
#   'probabilities': array([0.56441295, 0.43558705], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8896909], dtype=float32),
#   'logistic': array([0.1312797], dtype=float32),
#   'probabilities': array([0.8687203 , 0.13127972], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6364636], dtype=float32),
#   'logistic': array([0.16294685], dtype=float32),
#   'probabilities': array([0.8370532 , 0.16294684], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.41155416], dtype=float32),
#   'logistic': array([0.60146046], dtype=float32),
#   'probabilities': array([0.39853954, 0.6014605 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.319021], dtype=float32),
#   'logistic': array([0.21098122], dtype=float32),
#   'probabilities': array([0.7890188 , 0.21098123], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.84029377], dtype=float32),
#   'logistic': array([0.3014729], dtype=float32),
#   'probabilities': array([0.69852704, 0.3014729 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6641676], dtype=float32),
#   'logistic': array([0.15920332], dtype=float32),
#   'probabilities': array([0.84079665, 0.15920332], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.3870916], dtype=float32),
#   'logistic': array([0.08416232], dtype=float32),
#   'probabilities': array([0.9158377 , 0.08416234], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6272945], dtype=float32),
#   'logistic': array([0.16420132], dtype=float32),
#   'probabilities': array([0.8357987 , 0.16420132], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3720222], dtype=float32),
#   'logistic': array([0.20229334], dtype=float32),
#   'probabilities': array([0.79770666, 0.20229332], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.24538583], dtype=float32),
#   'logistic': array([0.56104046], dtype=float32),
#   'probabilities': array([0.43895954, 0.56104046], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.7772965], dtype=float32),
#   'logistic': array([0.31490287], dtype=float32),
#   'probabilities': array([0.68509716, 0.31490284], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.326133], dtype=float32),
#   'logistic': array([0.2097997], dtype=float32),
#   'probabilities': array([0.7902003 , 0.20979974], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.11164731], dtype=float32),
#   'logistic': array([0.5278829], dtype=float32),
#   'probabilities': array([0.47211716, 0.5278829 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.9184191], dtype=float32),
#   'logistic': array([0.28528014], dtype=float32),
#   'probabilities': array([0.7147199, 0.2852801], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.00837094], dtype=float32),
#   'logistic': array([0.49790728], dtype=float32),
#   'probabilities': array([0.5020927 , 0.49790728], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5025204], dtype=float32),
#   'logistic': array([0.18204993], dtype=float32),
#   'probabilities': array([0.81795007, 0.1820499 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5224767], dtype=float32),
#   'logistic': array([0.17909712], dtype=float32),
#   'probabilities': array([0.8209029, 0.1790971], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4161819], dtype=float32),
#   'logistic': array([0.19526085], dtype=float32),
#   'probabilities': array([0.8047391 , 0.19526082], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.3164108], dtype=float32),
#   'logistic': array([0.78858393], dtype=float32),
#   'probabilities': array([0.21141605, 0.78858393], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.02259129], dtype=float32),
#   'logistic': array([0.49435243], dtype=float32),
#   'probabilities': array([0.5056476 , 0.49435243], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2054603], dtype=float32),
#   'logistic': array([0.23050526], dtype=float32),
#   'probabilities': array([0.7694947 , 0.23050529], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8014781], dtype=float32),
#   'logistic': array([0.14167121], dtype=float32),
#   'probabilities': array([0.8583287 , 0.14167123], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7649933], dtype=float32),
#   'logistic': array([0.14616606], dtype=float32),
#   'probabilities': array([0.853834  , 0.14616607], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.81624705], dtype=float32),
#   'logistic': array([0.3065609], dtype=float32),
#   'probabilities': array([0.6934391, 0.3065609], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.55813354], dtype=float32),
#   'logistic': array([0.63602054], dtype=float32),
#   'probabilities': array([0.36397943, 0.6360206 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.3029598], dtype=float32),
#   'logistic': array([0.2136673], dtype=float32),
#   'probabilities': array([0.78633267, 0.2136673 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.20946652], dtype=float32),
#   'logistic': array([0.447824], dtype=float32),
#   'probabilities': array([0.552176, 0.447824], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.7499236], dtype=float32),
#   'logistic': array([0.32083797], dtype=float32),
#   'probabilities': array([0.679162  , 0.32083794], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.6075077], dtype=float32),
#   'logistic': array([0.35262793], dtype=float32),
#   'probabilities': array([0.647372 , 0.3526279], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.18389493], dtype=float32),
#   'logistic': array([0.5458446], dtype=float32),
#   'probabilities': array([0.4541554, 0.5458446], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.1704484], dtype=float32),
#   'logistic': array([0.23677397], dtype=float32),
#   'probabilities': array([0.76322603, 0.23677394], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.9640432], dtype=float32),
#   'logistic': array([0.27606943], dtype=float32),
#   'probabilities': array([0.7239306, 0.2760694], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7513847], dtype=float32),
#   'logistic': array([0.14787263], dtype=float32),
#   'probabilities': array([0.8521274 , 0.14787263], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7576388], dtype=float32),
#   'logistic': array([0.14708626], dtype=float32),
#   'probabilities': array([0.8529137, 0.1470863], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.84679216], dtype=float32),
#   'logistic': array([0.30010623], dtype=float32),
#   'probabilities': array([0.69989383, 0.30010623], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.5879634], dtype=float32),
#   'logistic': array([0.6428977], dtype=float32),
#   'probabilities': array([0.35710227, 0.6428977 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.5730815], dtype=float32),
#   'logistic': array([0.17177752], dtype=float32),
#   'probabilities': array([0.82822245, 0.17177755], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4632157], dtype=float32),
#   'logistic': array([0.18797597], dtype=float32),
#   'probabilities': array([0.81202406, 0.18797599], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.713534], dtype=float32),
#   'logistic': array([0.32881844], dtype=float32),
#   'probabilities': array([0.67118156, 0.3288184 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.7809312], dtype=float32),
#   'logistic': array([0.31411922], dtype=float32),
#   'probabilities': array([0.6858808 , 0.31411925], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1483662], dtype=float32),
#   'logistic': array([0.24078766], dtype=float32),
#   'probabilities': array([0.7592124 , 0.24078764], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.0658793], dtype=float32),
#   'logistic': array([0.11245766], dtype=float32),
#   'probabilities': array([0.8875423 , 0.11245767], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5483582], dtype=float32),
#   'logistic': array([0.17532352], dtype=float32),
#   'probabilities': array([0.82467645, 0.17532352], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.9508996], dtype=float32),
#   'logistic': array([0.27870396], dtype=float32),
#   'probabilities': array([0.721296 , 0.2787039], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5452816], dtype=float32),
#   'logistic': array([0.1757688], dtype=float32),
#   'probabilities': array([0.8242312, 0.1757688], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.07581532], dtype=float32),
#   'logistic': array([0.48105526], dtype=float32),
#   'probabilities': array([0.51894474, 0.48105523], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3263593], dtype=float32),
#   'logistic': array([0.20976225], dtype=float32),
#   'probabilities': array([0.7902378 , 0.20976222], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.58554655], dtype=float32),
#   'logistic': array([0.6423427], dtype=float32),
#   'probabilities': array([0.35765734, 0.6423427 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.21350473], dtype=float32),
#   'logistic': array([0.5531744], dtype=float32),
#   'probabilities': array([0.44682568, 0.5531744 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.8895793], dtype=float32),
#   'logistic': array([0.29119664], dtype=float32),
#   'probabilities': array([0.70880336, 0.29119667], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9199181], dtype=float32),
#   'logistic': array([0.12787068], dtype=float32),
#   'probabilities': array([0.8721293 , 0.12787071], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6962682], dtype=float32),
#   'logistic': array([0.1549533], dtype=float32),
#   'probabilities': array([0.8450467 , 0.15495329], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.7430853], dtype=float32),
#   'logistic': array([0.32232985], dtype=float32),
#   'probabilities': array([0.6776702 , 0.32232985], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4663341], dtype=float32),
#   'logistic': array([0.18750045], dtype=float32),
#   'probabilities': array([0.8124996 , 0.18750046], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9479313], dtype=float32),
#   'logistic': array([0.12477908], dtype=float32),
#   'probabilities': array([0.8752209 , 0.12477911], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.5315056], dtype=float32),
#   'logistic': array([0.3701658], dtype=float32),
#   'probabilities': array([0.6298342, 0.3701658], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.78429157], dtype=float32),
#   'logistic': array([0.3133957], dtype=float32),
#   'probabilities': array([0.6866043, 0.3133957], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3437734], dtype=float32),
#   'logistic': array([0.2068902], dtype=float32),
#   'probabilities': array([0.7931098 , 0.20689021], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.3410836], dtype=float32),
#   'logistic': array([0.5844537], dtype=float32),
#   'probabilities': array([0.4155463, 0.5844537], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.09223], dtype=float32),
#   'logistic': array([0.2511986], dtype=float32),
#   'probabilities': array([0.7488014, 0.2511986], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.09776026], dtype=float32),
#   'logistic': array([0.5244206], dtype=float32),
#   'probabilities': array([0.47557938, 0.5244206 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-2.9888122], dtype=float32),
#   'logistic': array([0.04793387], dtype=float32),
#   'probabilities': array([0.9520661 , 0.04793387], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.00060141], dtype=float32),
#   'logistic': array([0.5001504], dtype=float32),
#   'probabilities': array([0.49984968, 0.5001504 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.4802859], dtype=float32),
#   'logistic': array([0.18538424], dtype=float32),
#   'probabilities': array([0.8146157 , 0.18538423], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)}]

# %% [markdown]
# ## Same job with DNN densily connected neural network
# #### densily means all units in L layer are connected all L+1 layer's units

# %%
# when we use DNN, we have change categorical column into embedding_column
embedded_column = tf.feature_column.embedding_column(assigned_group,dimension=4)

# %%
# include embedded column
feature_cols = [num_preg,gluc_concent,bld_press,tri,insul,bmi,pedi,embedded_column,bucketized_age]

# %%
DNN_input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train, batch_size= 10, num_epochs= 1000, shuffle= False)

# %%
# 1st layer has 10 units, 2nd layer has 8 units. so on
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,8,6], feature_columns= feature_cols, n_classes= 2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/9c/883h376s53500dcqng4b4nj00000gn/T/tmpzdw4qgf1
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/9c/883h376s53500dcqng4b4nj00000gn/T/tmpzdw4qgf1', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1c43147748>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
dnn_model.train(input_fn=DNN_input_func, steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/feature_column/feature_column_v2.py:2997: VocabularyListCategoricalColumn._num_buckets (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed after 2018-11-30.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /var/folders/9c/883h376s53500dcqng4b4nj00000gn/T/tmpzdw4qgf1/model.ckpt.
# INFO:tensorflow:loss = 7.5070543, step = 1
# INFO:tensorflow:global_step/sec: 166.601
# INFO:tensorflow:loss = 7.0872602, step = 101 (0.600 sec)
# INFO:tensorflow:global_step/sec: 255.549
# INFO:tensorflow:loss = 4.0889583, step = 201 (0.391 sec)
# INFO:tensorflow:global_step/sec: 120.841
# INFO:tensorflow:loss = 5.8774576, step = 301 (0.829 sec)
# INFO:tensorflow:global_step/sec: 271.76
# INFO:tensorflow:loss = 6.1805997, step = 401 (0.366 sec)
# INFO:tensorflow:global_step/sec: 313.721
# INFO:tensorflow:loss = 5.900881, step = 501 (0.321 sec)
# INFO:tensorflow:global_step/sec: 274.334
# INFO:tensorflow:loss = 4.1915092, step = 601 (0.364 sec)
# INFO:tensorflow:global_step/sec: 309.878
# INFO:tensorflow:loss = 5.318925, step = 701 (0.323 sec)
# INFO:tensorflow:global_step/sec: 272.055
# INFO:tensorflow:loss = 3.2014413, step = 801 (0.372 sec)
# INFO:tensorflow:global_step/sec: 280.851
# INFO:tensorflow:loss = 1.6165478, step = 901 (0.356 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/9c/883h376s53500dcqng4b4nj00000gn/T/tmpzdw4qgf1/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.4618862.

# %%
DNN_test_input_func = tf.estimator.inputs.pandas_input_fn(x= X_test, y= y_test, batch_size=10, num_epochs= 1, shuffle= False)

# %%
DNN_test_results = dnn_model.evaluate(input_fn= DNN_test_input_func, steps= 1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-11T19:18:48Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/9c/883h376s53500dcqng4b4nj00000gn/T/tmpzdw4qgf1/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-04-11-19:18:49
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.72047246, accuracy_baseline = 0.66141737, auc = 0.80775887, auc_precision_recall = 0.6517005, average_loss = 0.5287718, global_step = 1000, label/mean = 0.33858266, loss = 5.165694, precision = 0.57009345, prediction/mean = 0.434112, recall = 0.7093023
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /var/folders/9c/883h376s53500dcqng4b4nj00000gn/T/tmpzdw4qgf1/model.ckpt-1000

# %%
DNN_test_results
# Out:
# {'accuracy': 0.72047246,
#  'accuracy_baseline': 0.66141737,
#  'auc': 0.80775887,
#  'auc_precision_recall': 0.6517005,
#  'average_loss': 0.5287718,
#  'label/mean': 0.33858266,
#  'loss': 5.165694,
#  'precision': 0.57009345,
#  'prediction/mean': 0.434112,
#  'recall': 0.7093023,
#  'global_step': 1000}
